# %%
# !git clone https://github.com/B-I-T-W-I-S-E-M-I-N-D-S/moshi-ditto-training-p2-lip-new-try2.git

# %%
# %cd moshi-ditto-training-p2-lip-new-try2

# %%
# !pip install huggingface_hub hf_transfer onnx rich transformers

# %%
# !pip uninstall -y torch torchaudio
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !bash ditto-train/scripts/setup_environment.sh

# %%
# !rm -r /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/checkpoints

# %%
# from huggingface_hub import snapshot_download
# import os

# repo_id = "Darknsu/HDTF_audio_video"
# download_dir = "/workspace/"

# # Create directory if it doesn't exist
# os.makedirs(download_dir, exist_ok=True)

# print("📥 Downloading HDTF dataset...")

# snapshot_download(
#     repo_id=repo_id,
#     repo_type="dataset",
#     local_dir=download_dir,
#     local_dir_use_symlinks=False,
# )

# print("✅ File downloaded to:", download_dir)

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "Darknsu/HDTF_MEAD"
download_dir = "/workspace/"

# Create directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

print("📥 Downloading HDTF dataset...")

snapshot_download(
    repo_id=repo_id,
    repo_type="dataset",
    local_dir=download_dir,
    local_dir_use_symlinks=False,
)

print("✅ File downloaded to:", download_dir)

# %%
# !tar -xzvf /workspace/HDTF_MEAD.tar.gz -C /workspace/

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "digital-avatar/ditto-talkinghead"
download_dir = "./ditto-train/checkpoints"

# Create directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

print("📥 Downloading full repository...")

snapshot_download(
    repo_id=repo_id,
    repo_type="model",   # important
    local_dir=download_dir,
    local_dir_use_symlinks=False,  # ensures real files, not symlinks
)

print("✅ Repo downloaded to:", download_dir)

# %% [markdown]
# ## 📥 Download Wav2Lip SyncNet Checkpoint
# Required for lip-sync loss during training. This is the pretrained "Expert Discriminator" from the Wav2Lip project (~25MB).

# %%
from huggingface_hub import snapshot_download
import os

repo_id = "Nekochu/Wav2Lip"
download_dir = "./ditto-train/checkpoints"

# Create directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

print("📥 Downloading full repository...")

snapshot_download(
    repo_id=repo_id,
    repo_type="model",   # important
    local_dir=download_dir,
    local_dir_use_symlinks=False,  # ensures real files, not symlinks
)

print("✅ Repo downloaded to:", download_dir)

# %%
# import os, urllib.request

# syncnet_url = "https://iiitaphyd-my.sharepoint.com/personal/radrabha_m_research_iiit_ac_in/_layouts/15/download.aspx?share=EQRvS3SS2xxJhBTVeBVOPo0BspTgznXpMHhaVdoKl5cojA"
# syncnet_dir = "./ditto-train/checkpoints"
# syncnet_path = os.path.join(syncnet_dir, "lipsync_expert.pth")

# os.makedirs(syncnet_dir, exist_ok=True)

# if not os.path.isfile(syncnet_path):
#     print("📥 Downloading Wav2Lip SyncNet checkpoint...")
#     try:
#         urllib.request.urlretrieve(syncnet_url, syncnet_path)
#         print(f"✅ SyncNet downloaded to: {syncnet_path}")
#     except Exception as e:
#         print(f"⚠️  Auto-download failed: {e}")
#         print(f"Please manually download lipsync_expert.pth from:")
#         print(f"  https://github.com/Rudrabha/Wav2Lip#getting-the-weights")
#         print(f"  → 'Expert Discriminator' link")
#         print(f"  Place it at: {syncnet_path}")
# else:
#     print(f"✅ SyncNet checkpoint already exists: {syncnet_path}")

# # Verify
# if os.path.isfile(syncnet_path):
#     size_mb = os.path.getsize(syncnet_path) / 1024 / 1024
#     print(f"   Size: {size_mb:.1f} MB")

# %%
# !apt update -qq
# !apt-get install -y ffmpeg libcudnn8 libcudnn8-dev 2>&1 | tail -5
# !apt-get install -y libgles2 libgl1-mesa-glx libegl1-mesa

# %%
# import os

# video_dir = "/workspace/HDTF/video"
# wav_dir = "/workspace/HDTF/wav"

# # Get filenames without extension
# video_files = {os.path.splitext(f)[0]: f for f in os.listdir(video_dir) if f.endswith(".mp4")}
# wav_files = {os.path.splitext(f)[0]: f for f in os.listdir(wav_dir) if f.endswith(".wav")}

# # Find common names
# common_names = list(set(video_files.keys()) & set(wav_files.keys()))

# # Keep only first 20 (you can shuffle if you want random)
# keep_names = set(common_names[:20])

# # Delete unwanted video files
# for name, filename in video_files.items():
#     if name not in keep_names:
#         os.remove(os.path.join(video_dir, filename))

# # Delete unwanted wav files
# for name, filename in wav_files.items():
#     if name not in keep_names:
#         os.remove(os.path.join(wav_dir, filename))

# print(f"Kept {len(keep_names)} matching files, removed the rest.")

# %%
# !python ./ditto-train/example/get_data_info_json_for_trainset_example.py

# %% [markdown]
# ## 🚀 Run Full Training Pipeline (with Lip-Sync Loss)
# This runs all phases:
# 1. Video processing (motion/eye/emotion features)
# 2. Bridge audio feature extraction
# 3. **Lip-sync feature preprocessing** (SyncNet embeddings, appearance features)
# 4. Data gathering
# 5. Training with lip-sync loss
#
# Set `USE_LIP_SYNC=0` to disable lip-sync loss and train with motion-only losses.

# %%
# !pip uninstall -y torch torchaudio
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !python /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/example/get_data_info_json_for_trainset_example.py

# %%
# !pip install --upgrade torchvision --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install --upgrade transformers accelerate huggingface_hub

# %%
# !HDTF_ROOT=/workspace/HDTF NUM_GPUS=8 USE_LIP_SYNC=1 bash ditto-train/scripts/prepare_and_train.sh

# %%
# !pip uninstall -y huggingface-hub
# !pip install "huggingface-hub<1.0.0,>=0.24"

# %%
#_aKHzCnOPrapIEwfnuxyQUszisfBqaRrTXQ

# %%
# !pip install -q huggingface_hub
from huggingface_hub import login

# Paste your token here
hf_token = ""
login(token=hf_token)



import os
from huggingface_hub import HfApi
from tqdm import tqdm

# --- CONFIGURATION ---

# Local folder you want to upload
local_folder = "./ditto-train/experiments/s2/bridge_ditto_hdtf_v1/ckpts"  # Replace with your folder path

# Hugging Face dataset repo info
repo_id = "Darknsu/MEAD_epoch_1000"  # Replace with your repo
repo_type = "dataset"

# Commit message
commit_message = "Upload entire folder with structure in one commit"

# --- UPLOAD FUNCTION ---
def upload_folder_single_commit(local_folder, repo_id, repo_type="dataset"):
    api = HfApi()

    print("📤 Uploading folder to Hugging Face with a single commit...")

    # Progress bar for local file count (optional)
    total_files = sum(len(files) for _, _, files in os.walk(local_folder))
    with tqdm(total=total_files, desc="Processing files") as pbar:
        for _, _, files in os.walk(local_folder):
            pbar.update(len(files))

    # Upload folder in a single commit
    api.upload_folder(
        folder_path=local_folder,
        repo_id=repo_id,
        repo_type=repo_type,
        commit_message=commit_message,
    )

    print("✅ Folder uploaded successfully in a single commit.")

# --- EXECUTE ---
upload_folder_single_commit(local_folder, repo_id, repo_type)
# Out:
# 📤 Uploading folder to Hugging Face with a single commit...
# Processing files: 100%|██████████| 26/26 [00:00<00:00, 44008.03it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✅ Folder uploaded successfully in a single commit.

# %%
# !HDTF_ROOT=/workspace/HDTF NUM_GPUS=8 USE_LIP_SYNC=1 LIP_SYNC_DEBUG=1 bash ditto-train/scripts/prepare_and_train.sh

# %%
# !HDTF_ROOT=/workspace/HDTF NUM_GPUS=8 USE_LIP_SYNC=1 bash ditto-train/scripts/prepare_and_train.sh
# Out:
#  11%|████▋                                       | 7/66 [00:04<00:24,  2.37it/s]
#  12%|█████▎                                      | 8/66 [00:05<00:22,  2.58it/s]
#  14%|██████                                      | 9/66 [00:05<00:20,  2.73it/s]
# [LipSync Debug] Step 65680, Epoch 996
#   x_recon shape: torch.Size([256, 80, 265])
#   x_recon requires_grad: True
#   x_recon range: [-0.6967, 1.4862]
#   debug images path: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/lip_debug
#   [DEBUG] No valid lip-sync samples in batch!
#
#  15%|██████▌                                    | 10/66 [00:05<00:19,  2.80it/s]
#  17%|███████▏                                   | 11/66 [00:06<00:18,  2.90it/s]
#  18%|███████▊                                   | 12/66 [00:06<00:18,  2.97it/s]
#  20%|████████▍                                  | 13/66 [00:06<00:17,  3.01it/s]
#  21%|█████████                                  | 14/66 [00:07<00:17,  3.05it/s]
#  23%|█████████▊                                 | 15/66 [00:07<00:16,  3.03it/s]
#  24%|██████████▍                                | 16/66 [00:07<00:16,  3.06it/s]
#  26%|███████████                                | 17/66 [00:08<00:15,  3.07it/s]
#  27%|███████████▋                               | 18/66 [00:08<00:15,  3.09it/s]
#  29%|████████████▍                              | 19/66 [00:08<00:15,  3.10it/s]
# [LipSync Debug] Step 65690, Epoch 996
#   x_recon shape: torch.Size([256, 80, 265])
#   x_recon requires_grad: True
#   x_recon range: [-0.7404, 1.5049]
#   debug images path: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/lip_debug
#   [DEBUG] No valid lip-sync samples in batch!
#
#  30%|█████████████                              | 20/66 [00:09<00:14,  3.07it/s]
#  32%|█████████████▋                             | 21/66 [00:09<00:14,  3.09it/s]
#  33%|██████████████▎                            | 22/66 [00:09<00:14,  3.11it/s]
#  35%|██████████████▉                            | 23/66 [00:09<00:13,  3.13it/s]
#  36%|███████████████▋                           | 24/66 [00:10<00:13,  3.14it/s]
#  38%|████████████████▎                          | 25/66 [00:10<00:13,  3.08it/s]
#  39%|████████████████▉                          | 26/66 [00:10<00:12,  3.11it/s]
#  41%|█████████████████▌                         | 27/66 [00:11<00:12,  3.12it/s]
#  42%|██████████████████▏                        | 28/66 [00:11<00:12,  3.13it/s]
#  44%|██████████████████▉                        | 29/66 [00:11<00:11,  3.14it/s]
# [LipSync Debug] Step 65700, Epoch 996
#   x_recon shape: torch.Size([256, 80, 265])
#   x_recon requires_grad: True
#   x_recon range: [-0.6685, 1.4941]
#   debug images path: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/lip_debug
#   [DEBUG] No valid lip-sync samples in batch!
#
#
#   x_recon shape: torch.Size([256, 80, 265])
#   x_recon requires_grad: True
#   x_recon range: [-0.6269, 1.4939]
#   debug images path: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/lip_debug
#   [DEBUG] No valid lip-sync samples in batch!
#
#  85%|████████████████████████████████████▍      | 56/66 [00:20<00:03,  3.09it/s]
#  86%|█████████████████████████████████████▏     | 57/66 [00:20<00:02,  3.12it/s]
#  88%|█████████████████████████████████████▊     | 58/66 [00:21<00:02,  3.04it/s]
#  89%|██████████████████████████████████████▍    | 59/66 [00:21<00:02,  3.09it/s]
#  91%|███████████████████████████████████████    | 60/66 [00:21<00:01,  3.13it/s]
#  92%|███████████████████████████████████████▋   | 61/66 [00:22<00:01,  3.12it/s]
#  94%|████████████████████████████████████████▍  | 62/66 [00:22<00:01,  3.16it/s]
#  95%|█████████████████████████████████████████  | 63/66 [00:22<00:00,  3.18it/s]
#  97%|█████████████████████████████████████████▋ | 64/66 [00:23<00:00,  3.20it/s]
#  98%|██████████████████████████████████████████▎| 65/66 [00:23<00:00,  3.22it/s]
# [LipSync Debug] Step 66000, Epoch 1000
#   x_recon shape: torch.Size([256, 80, 265])
#   x_recon requires_grad: True
#   x_recon range: [-0.6288, 1.4676]
#   debug images path: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/lip_debug
#   [DEBUG] No valid lip-sync samples in batch!
#
# 100%|███████████████████████████████████████████| 66/66 [00:23<00:00,  2.75it/s]
# Tue Apr 21 10:27:12 2026Tue Apr 21 10:27:12 2026Tue Apr 21 10:27:12 2026Tue Apr 21 10:27:12 2026Tue Apr 21 10:27:12 2026Tue Apr 21 10:27:12 2026  done.Tue Apr 21 10:27:12 2026  done.
# done.
#
# Tue Apr 21 10:27:12 2026 Training complete.
# done.
#
# Tue Apr 21 10:27:12 2026 Training complete.
#
# Tue Apr 21 10:27:12 2026 Training complete.
#  done. done.done.
#
#
# Tue Apr 21 10:27:12 2026 Training complete.
#
# Tue Apr 21 10:27:12 2026 Training complete.
#
#
#
# Tue Apr 21 10:27:12 2026 Training complete.
# Tue Apr 21 10:27:12 2026 Training complete.
#
# [MODEL SAVED at Epoch 1000] (5)
# [BEST MODEL] Epoch 1000, loss=0.001172 → /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/ckpts/lmdm_v0.4_hubert.pth
# 100%|█████████████████████████████████████| 1000/1000 [7:08:36<00:00, 25.72s/it]
# Tue Apr 21 10:27:13 2026 done.
#
# Tue Apr 21 10:27:13 2026 Training complete.
# [rank0]:[W421 10:27:14.406883159 ProcessGroupNCCL.cpp:1250] Warning: WARNING: process group has NOT been destroyed before we destruct ProcessGroupNCCL. On normal program exit, the application should call destroy_process_group to ensure that any pending NCCL operations have finished in this process. In rare cases this process can exit before this point and block the progress of another member of the process group. This constraint has always been present,  but this warning has only been added since PyTorch 2.4 (function operator())
#
#
# ═══════════════════════════════════════════════════════════════
#    ✅  Training Pipeline Complete!
#
#    Time elapsed: 25827s
#
#    Checkpoints: /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/ckpts/
#    Loss log:    /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/experiments/s2/bridge_ditto_hdtf_v1/loss.log
# ═══════════════════════════════════════════════════════════════

# %%
# !ls /workspace/moshi-ditto-training-p2-lip-new-try2/ditto-train/checkpoints/ditto_pytorch/models
# Out:
# appearance_extractor.pth  lmdm_v0.4_hubert.pth	stitch_network.pth
# decoder.pth		  motion_extractor.pth	warp_network.pth
